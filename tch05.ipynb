# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.datasets import mnist, fashion_mnist
from tensorflow.keras.layers import  Conv2D, MaxPool2D

# %%
(x_train, y_train),(x_test, y_test) = mnist.load_data()

# %%
x_train = x_train.reshape(-1, 28,28,1)
x_test  = x_test.reshape(-1,28,28,1)

# %% [markdown]
# x_train.reshape(-1, 28,28,1)
# 4D
# -1(샘플 수:자동), 이미지 높이, 이미지 넓이, 채널 수

# %%
print(x_train.shape, x_test.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %%
x_train = x_train.astype(np.float32) / 255.0
x_test = x_test.astype(np.float32) / 255.0

# %%
cnn = Sequential()
cnn.add(Conv2D(input_shape=(28,28,1),kernel_size=(3,3),
               filters=32, activation='relu'))

# %%
cnn.add(Conv2D(kernel_size=(3,3),filters=64, activation='relu'))

cnn.add(MaxPool2D(pool_size=(2,2)))
cnn.add(Dropout(0.25))
cnn.add(Flatten())
cnn.add(Dense(128, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(10, activation='softmax'))

# %%
cnn.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %%
hist = cnn.fit(x_train, y_train, batch_size=128, epochs=30, validation_data=(x_test,y_test))
# Out:
# Epoch 1/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 76s 160ms/step - accuracy: 0.9234 - loss: 0.2526 - val_accuracy: 0.9832 - val_loss: 0.0560
# Epoch 2/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 73s 156ms/step - accuracy: 0.9729 - loss: 0.0920 - val_accuracy: 0.9880 - val_loss: 0.0378
# Epoch 3/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 75s 160ms/step - accuracy: 0.9795 - loss: 0.0683 - val_accuracy: 0.9868 - val_loss: 0.0393
# Epoch 4/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 74s 158ms/step - accuracy: 0.9831 - loss: 0.0556 - val_accuracy: 0.9885 - val_loss: 0.0348
# Epoch 5/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 74s 157ms/step - accuracy: 0.9855 - loss: 0.0473 - val_accuracy: 0.9909 - val_loss: 0.0283
# Epoch 6/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 73s 155ms/step - accuracy: 0.9869 - loss: 0.0417 - val_accuracy: 0.9902 - val_loss: 0.0303
# Epoch 7/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 76s 163ms/step - accuracy: 0.9893 - loss: 0.0339 - val_accuracy: 0.9901 - val_loss: 0.0316
# Epoch 8/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 75s 161ms/step - accuracy: 0.9895 - loss: 0.0340 - val_accuracy: 0.9924 - val_loss: 0.0280
# Epoch 9/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 74s 157ms/step - accuracy: 0.9909 - loss: 0.0284 - val_accuracy: 0.9915 - val_loss: 0.0276
# Epoch 10/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 153ms/step - accuracy: 0.9912 - loss: 0.0270 - val_accuracy: 0.9917 - val_loss: 0.0299
# Epoch 11/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 73s 156ms/step - accuracy: 0.9919 - loss: 0.0246 - val_accuracy: 0.9922 - val_loss: 0.0287
# Epoch 12/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 155ms/step - accuracy: 0.9922 - loss: 0.0241 - val_accuracy: 0.9918 - val_loss: 0.0286
# Epoch 13/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 73s